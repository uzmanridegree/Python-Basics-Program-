# %% [markdown]
# <a href="https://colab.research.google.com/github/uzmanridegree/Python-Basics-Program-/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'weight' : a2,
    'friends' : a3,
    'cousins': a4,
    'projects': a5
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       38      64       17        8        56
# 1       23      65       10        5        48
# 2       96      54       10        5        32
# 3       79      59       10        7        54
# 4       42      65       17        6        37
# ..     ...     ...      ...      ...       ...
# 995     16      62       19       10        67
# 996     92      65       16        7        29
# 997     45      57       20        6        62
# 998      1      59       20        5        67
# 999     13      56       12        7        32
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     50.520000    60.011000    15.011000     7.525000    50.611000
# std      28.271981     6.228778     3.195166     1.731003    17.333209
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      27.000000    54.000000    12.000000     6.000000    35.000000
# 50%      50.500000    60.000000    15.000000     8.000000    52.000000
# 75%      75.000000    65.250000    18.000000     9.000000    65.250000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friends18 = df1['friends']>18

# %%
df1[friends18]
# Out:
#      grade  weight  friends  cousins  projects
# 5       60      54       20       10        56
# 13      28      57       20        8        24
# 14      32      50       19        8        34
# 20      26      66       20        7        69
# 28      81      57       19        9        68
# ..     ...     ...      ...      ...       ...
# 979      1      63       19        8        72
# 990     11      50       19        5        59
# 995     16      62       19       10        67
# 997     45      57       20        6        62
# 998      1      59       20        5        67
#
# [184 rows x 5 columns]

# %%
df1[friends18].describe()
# Out:
#             grade      weight     friends     cousins    projects
# count  184.000000  184.000000  184.000000  184.000000  184.000000
# mean    49.983696   60.157609   19.532609    7.494565   50.668478
# std     27.890002    6.453884    0.500297    1.733619   17.221282
# min      1.000000   50.000000   19.000000    5.000000   20.000000
# 25%     26.000000   54.000000   19.000000    6.000000   34.000000
# 50%     53.000000   61.000000   20.000000    8.000000   53.500000
# 75%     74.000000   66.000000   20.000000    9.000000   65.000000
# max     99.000000   70.000000   20.000000   10.000000   80.000000

# %%
grade98 = df1['grade']>98

# %%
df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 33     100      66       18        5        23
# 40      99      54       19        5        64
# 134    100      69       14       10        53
# 181    100      64       12        9        52
# 186     99      59       10        5        32
# 238     99      50       13       10        58
# 400    100      69       11        6        57
# 404     99      60       14       10        27
# 476    100      65       17        8        50
# 592     99      56       20        5        35
# 641     99      57       11        9        58
# 768     99      51       13        5        30
# 982    100      58       14        7        33

# %%
df1[friends18 & grade98] ['friends']
# Out:
# 40     19
# 592    20
# Name: friends, dtype: int64

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friends18 & grade98].plot()
# Out:
# <Axes: >

# %%
df1[friends18 & grade98].plot(x= 'grade',y= 'projects',kind='scatter')
# Out:
# <Axes: xlabel='grade', ylabel='projects'>

# %%
df1[friends18 & grade98].plot(x= ['grade','friends'],y= ['projects','weight'],kind='scatter',title= 'sample Graph')
plt.xlabel('x Axis')
plt.ylabel('y Axis')
plt.legend('Test Data')
plt.show()

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
fdf=df1[friends18 & grade98]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 40      99      54       19        5        64
# 592     99      56       20        5        35

# %%
df1.to_csv('/uzmaData.csv')
