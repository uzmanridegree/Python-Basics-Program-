# %% [markdown]
# <a href="https://colab.research.google.com/github/uzmanridegree/Python-Basics-Program-/blob/main/Requests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url = 'https://jsonplaceholder.typicode.com/posts'

# %%
response = requests.get(url=url)

# %%
response.json()
# Out:
# [{'userId': 1,
#   'id': 1,
#   'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#   'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'},
#  {'userId': 1,
#   'id': 2,
#   'title': 'qui est esse',
#   'body': 'est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla'},
#  {'userId': 1,
#   'id': 3,
#   'title': 'ea molestias quasi exercitationem repellat qui ipsa sit aut',
#   'body': 'et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut'},
#  {'userId': 1,
#   'id': 4,
#   'title': 'eum et est occaecati',
# ...

# %%
type(response.json())
# Out:
# list

# %%
for _ in response.json():
    print(f'post Number is {_["id"]}')
# Out:
# post Number is 1
# post Number is 2
# post Number is 3
# post Number is 4
# post Number is 5
# post Number is 6
# post Number is 7
# post Number is 8
# post Number is 9
# post Number is 10
# post Number is 11
# post Number is 12
# post Number is 13
# post Number is 14
# post Number is 15
# post Number is 16
# post Number is 17
# post Number is 18
# post Number is 19
# post Number is 20
# post Number is 21
# post Number is 22
# post Number is 23
# post Number is 24
# post Number is 25
# post Number is 26
# post Number is 27
# post Number is 28
# post Number is 29
# post Number is 30
# post Number is 31
# post Number is 32
# post Number is 33
# post Number is 34
# post Number is 35
# post Number is 36
# post Number is 37
# post Number is 38
# post Number is 39
# post Number is 40
# post Number is 41
# post Number is 42
# post Number is 43
# post Number is 44
# post Number is 45
# post Number is 46
# post Number is 47
# post Number is 48
# post Number is 49
# post Number is 50
# ...

# %%
import requests
url = 'https://api.github.com/search/repositories'

# %%
parms = {
    'q' : 'requests+language: python',
    'sort' : 'stars',
    'order' : 'desc'
}

# %%
response = requests.get(url = url,params=parms)

# %%
response.json()
# Out:
# {'total_count': 3,
#  'incomplete_results': False,
#  'items': [{'id': 751007590,
#    'node_id': 'R_kgDOLMN3Zg',
#    'name': 'WordsPy',
#    'full_name': 'eymenefealtun/WordsPy',
#    'private': False,
#    'owner': {'login': 'eymenefealtun',
#     'id': 125976557,
#     'node_id': 'U_kgDOB4I_7Q',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/125976557?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/eymenefealtun',
#     'html_url': 'https://github.com/eymenefealtun',
#     'followers_url': 'https://api.github.com/users/eymenefealtun/followers',
#     'following_url': 'https://api.github.com/users/eymenefealtun/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/eymenefealtun/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/eymenefealtun/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/eymenefealtun/subscriptions',
# ...
