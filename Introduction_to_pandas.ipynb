# %% [markdown]
# <a href="https://colab.research.google.com/github/uzmanridegree/Python-Basics-Program-/blob/main/Introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive
# Out:
# <module 'google.colab.drive' from '/usr/local/lib/python3.10/dist-packages/google/colab/drive.py'>

# %%
ds = pd.read_csv('/content/drive/MyDrive/Card applications/Credit_Card_Applications.csv')

# %%
ds
# Out:
#      CustomerID  A1     A2      A3  A4  A5  A6     A7  A8  A9  A10  A11  A12  \
# 0      15776156   1  22.08  11.460   2   4   4  1.585   0   0    0    1    2
# 1      15739548   0  22.67   7.000   2   8   4  0.165   0   0    0    0    2
# 2      15662854   0  29.58   1.750   1   4   4  1.250   0   0    0    1    2
# 3      15687688   0  21.67  11.500   1   5   3  0.000   1   1   11    1    2
# 4      15715750   1  20.17   8.170   2   6   4  1.960   1   1   14    0    2
# ..          ...  ..    ...     ...  ..  ..  ..    ...  ..  ..  ...  ...  ...
# 685    15808223   1  31.57  10.500   2  14   4  6.500   1   0    0    0    2
# 686    15769980   1  20.67   0.415   2   8   4  0.125   0   0    0    0    2
# 687    15675450   0  18.83   9.540   2   6   4  0.085   1   0    0    0    2
# 688    15776494   0  27.42  14.500   2  14   8  3.085   1   1    1    0    2
# 689    15592412   1  41.00   0.040   2  10   4  0.040   0   1    1    0    1
#
#      A13   A14  Class
# 0    100  1213      0
# 1    160     1      0
# 2    280     1      0
# 3      0     1      1
# 4     60   159      1
# ..   ...   ...    ...
# 685    0     1      1
# 686    0    45      0
# 687  100     1      1
# 688  120    12      1
# 689  560     1      1
#
# [690 rows x 16 columns]

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))
idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [48,
#   10,
#   44,
#   95,
#   2,
#   60,
#   13,
#   36,
#   9,
#   0,
#   64,
#   89,
#   65,
#   64,
#   75,
#   1,
#   80,
#   82,
#   34,
#   62,
#   26,
#   34,
#   57,
#   14,
#   56,
#   12,
#   81,
#   87,
#   19,
#   71,
#   68,
#   24,
#   38,
#   78,
#   28,
#   93,
#   91,
#   13,
#   96,
#   22,
#   24,
#   16,
#   10,
#   35,
#   6,
#   15,
#   44,
#   61,
#   81,
#   14,
#   54,
#   3,
#   79,
#   22,
#   7,
#   97,
#   25,
#   37,
#   97,
#   55,
#   82,
#   100,
#   84,
#   89,
#   15,
#   27,
#   42,
#   25,
#   70,
#   49,
#   85,
#   51,
#   9,
#   11,
#   21,
#   40,
#   18,
#   90,
#   81,
#   7,
#   6,
#   65,
#   23,
#   76,
#   45,
#   15,
#   64,
#   82,
#   81,
#   65,
#   44,
#   73,
#   68,
#   1,
#   17,
#   58,
#   40,
#   28,
#   30,
#   89],
#  'Height': [41,
#   14,
#   28,
#   59,
#   86,
#   68,
#   74,
#   7,
#   75,
#   0,
#   89,
#   48,
#   38,
#   7,
#   51,
#   59,
#   36,
#   79,
#   87,
#   94,
#   50,
#   74,
#   32,
#   26,
#   72,
#   1,
#   70,
#   11,
#   15,
#   19,
#   17,
#   22,
#   23,
#   43,
#   4,
#   28,
#   78,
#   72,
#   21,
#   70,
#   50,
#   65,
#   15,
#   2,
#   72,
#   15,
#   74,
#   23,
#   19,
#   30,
#   72,
#   92,
#   19,
#   92,
#   8,
#   31,
#   12,
#   17,
#   10,
#   15,
#   84,
#   80,
#   86,
#   27,
#   69,
#   42,
#   41,
#   37,
#   14,
#   62,
#   82,
#   47,
#   66,
#   67,
#   43,
#   8,
#   22,
#   78,
#   16,
#   27,
#   22,
#   96,
#   85,
#   15,
#   83,
#   74,
#   36,
#   92,
#   60,
#   77,
#   95,
#   29,
#   34,
#   38,
#   75,
#   56,
#   48,
#   97,
#   26,
#   16],
#  'Weight': [15,
#   56,
#   77,
#   87,
#   19,
#   74,
#   63,
#   76,
#   12,
#   71,
#   7,
#   63,
#   26,
#   7,
#   70,
#   37,
#   12,
#   82,
#   64,
#   90,
#   4,
#   62,
#   0,
#   43,
#   3,
#   98,
#   83,
#   92,
#   87,
#   44,
#   29,
#   77,
#   67,
#   84,
#   31,
#   39,
#   98,
#   80,
#   45,
#   37,
#   2,
#   54,
#   67,
#   95,
#   47,
#   67,
#   23,
#   98,
#   74,
#   39,
#   87,
#   34,
#   89,
#   91,
#   25,
#   42,
#   4,
#   99,
#   100,
#   17,
#   56,
#   86,
#   35,
#   88,
#   39,
#   11,
#   53,
#   8,
#   7,
#   82,
#   99,
#   63,
#   27,
#   23,
#   11,
#   49,
#   33,
#   83,
#   29,
#   45,
#   10,
#   31,
#   92,
#   34,
#   77,
#   49,
#   98,
#   20,
#   6,
#   30,
#   32,
#   5,
#   13,
#   61,
#   20,
#   89,
#   62,
#   71,
#   65,
#   2],
#  'Speed': [56,
#   87,
#   22,
#   72,
#   77,
#   90,
#   55,
#   19,
#   34,
#   37,
#   85,
#   82,
#   93,
#   92,
#   57,
#   18,
#   0,
#   82,
#   64,
#   12,
#   98,
#   42,
#   76,
#   23,
#   51,
#   65,
#   77,
#   76,
#   0,
#   25,
#   74,
#   46,
#   47,
#   62,
#   30,
#   36,
#   76,
#   54,
#   0,
#   68,
#   94,
#   9,
#   64,
#   85,
#   67,
#   50,
#   83,
#   43,
#   15,
#   11,
#   72,
#   48,
#   81,
#   44,
#   36,
#   36,
#   84,
#   69,
#   18,
#   80,
#   30,
#   70,
#   91,
#   21,
#   46,
#   76,
#   50,
#   40,
#   33,
#   71,
#   55,
#   50,
#   92,
#   10,
#   22,
#   2,
#   54,
#   37,
#   74,
#   30,
#   14,
#   35,
#   84,
#   48,
#   37,
#   0,
#   80,
#   36,
#   27,
#   66,
#   88,
#   74,
#   41,
#   47,
#   75,
#   37,
#   0,
#   65,
#   71,
#   62]}

# %%
df1 = pd.DataFrame(idata)

# %%
df1
# Out:
#     Age  Height  Weight  Speed
# 0    48      41      15     56
# 1    10      14      56     87
# 2    44      28      77     22
# 3    95      59      87     72
# 4     2      86      19     77
# ..  ...     ...     ...    ...
# 95   58      56      89     37
# 96   40      48      62      0
# 97   28      97      71     65
# 98   30      26      65     71
# 99   89      16       2     62
#
# [100 rows x 4 columns]

# %%
df1.head(10)
# Out:
#    Age  Height  Weight  Speed
# 0   48      41      15     56
# 1   10      14      56     87
# 2   44      28      77     22
# 3   95      59      87     72
# 4    2      86      19     77
# 5   60      68      74     90
# 6   13      74      63     55
# 7   36       7      76     19
# 8    9      75      12     34
# 9    0       0      71     37

# %%
df1.tail(10)
# Out:
#     Age  Height  Weight  Speed
# 90   44      95      32     88
# 91   73      29       5     74
# 92   68      34      13     41
# 93    1      38      61     47
# 94   17      75      20     75
# 95   58      56      89     37
# 96   40      48      62      0
# 97   28      97      71     65
# 98   30      26      65     71
# 99   89      16       2     62

# %%
df1.describe()
# Out:
#               Age      Height      Weight       Speed
# count  100.000000  100.000000  100.000000  100.000000
# mean    46.890000   46.730000   50.590000   51.900000
# std     30.171528   28.904879   31.031784   26.966684
# min      0.000000    0.000000    0.000000    0.000000
# 25%     18.750000   20.500000   24.500000   33.750000
# 50%     44.000000   42.500000   49.000000   52.500000
# 75%     75.250000   74.000000   77.750000   75.250000
# max    100.000000   97.000000  100.000000   98.000000

# %%
df1['Age']
# Out:
# 0     48
# 1     10
# 2     44
# 3     95
# 4      2
#       ..
# 95    58
# 96    40
# 97    28
# 98    30
# 99    89
# Name: Age, Length: 100, dtype: int64

# %%
df1[['Age','Height']]
# Out:
#     Age  Height
# 0    48      41
# 1    10      14
# 2    44      28
# 3    95      59
# 4     2      86
# ..  ...     ...
# 95   58      56
# 96   40      48
# 97   28      97
# 98   30      26
# 99   89      16
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['Age','Height']]
# Out:
#    Age  Height
# 0   48      41
# 3   95      59

# %%
df2 = df1[['Age','Height']]

# %%
df2.describe()
# Out:
#               Age      Height
# count  100.000000  100.000000
# mean    46.890000   46.730000
# std     30.171528   28.904879
# min      0.000000    0.000000
# 25%     18.750000   20.500000
# 50%     44.000000   42.500000
# 75%     75.250000   74.000000
# max    100.000000   97.000000

# %%
df1.sort_index(ascending=False)
# Out:
#     Age  Height  Weight  Speed
# 99   89      16       2     62
# 98   30      26      65     71
# 97   28      97      71     65
# 96   40      48      62      0
# 95   58      56      89     37
# ..  ...     ...     ...    ...
# 4     2      86      19     77
# 3    95      59      87     72
# 2    44      28      77     22
# 1    10      14      56     87
# 0    48      41      15     56
#
# [100 rows x 4 columns]

# %%
df2[0::2]
# Out:
#     Age  Height
# 0    48      41
# 2    44      28
# 4     2      86
# 6    13      74
# 8     9      75
# 10   64      89
# 12   65      38
# 14   75      51
# 16   80      36
# 18   34      87
# 20   26      50
# 22   57      32
# 24   56      72
# 26   81      70
# 28   19      15
# 30   68      17
# 32   38      23
# 34   28       4
# 36   91      78
# 38   96      21
# 40   24      50
# 42   10      15
# 44    6      72
# 46   44      74
# 48   81      19
# 50   54      72
# 52   79      19
# 54    7       8
# 56   25      12
# 58   97      10
# 60   82      84
# 62   84      86
# 64   15      69
# 66   42      41
# 68   70      14
# 70   85      82
# 72    9      66
# 74   21      43
# 76   18      22
# 78   81      16
# 80    6      22
# 82   23      85
# 84   45      83
# 86   64      36
# 88   81      60
# 90   44      95
# 92   68      34
# 94   17      75
# 96   40      48
# 98   30      26

# %%
df1[0:2]
# Out:
#    Age  Height  Weight  Speed
# 0   48      41      15     56
# 1   10      14      56     87

# %%
df1[0::2].describe()
# Out:
#              Age     Height      Weight      Speed
# count  50.000000  50.000000   50.000000  50.000000
# mean   46.920000  48.500000   43.880000  55.000000
# std    28.784803  27.851831   32.127704  28.577856
# min     2.000000   4.000000    0.000000   0.000000
# 25%    21.500000  22.000000   13.500000  33.250000
# 50%    44.000000  45.500000   34.000000  56.500000
# 75%    73.750000  74.000000   69.250000  77.000000
# max    97.000000  95.000000  100.000000  98.000000

# %%
# Filter
df1['Weight'] > 50
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
#       ...
# 95     True
# 96     True
# 97     True
# 98     True
# 99    False
# Name: Weight, Length: 100, dtype: bool

# %%
# Filter
filter1 = df1['Weight'] > 50

# %%
df1[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    10      14      56     87
# 2    44      28      77     22
# 3    95      59      87     72
# 5    60      68      74     90
# 6    13      74      63     55
# 7    36       7      76     19
# 9     0       0      71     37
# 11   89      48      63     82
# 14   75      51      70     57
# 17   82      79      82     82
# 18   34      87      64     64
# 19   62      94      90     12
# 21   34      74      62     42
# 25   12       1      98     65
# 26   81      70      83     77
# 27   87      11      92     76
# 28   19      15      87      0
# 31   24      22      77     46
# 32   38      23      67     47
# 33   78      43      84     62
# 36   91      78      98     76
# 37   13      72      80     54
# 41   16      65      54      9
# 42   10      15      67     64
# 43   35       2      95     85
# 45   15      15      67     50
# 47   61      23      98     43
# 48   81      19      74     15
# 50   54      72      87     72
# 52   79      19      89     81
# 53   22      92      91     44
# 57   37      17      99     69
# 58   97      10     100     18
# 60   82      84      56     30
# 61  100      80      86     70
# 63   89      27      88     21
# 66   42      41      53     50
# 69   49      62      82     71
# 70   85      82      99     55
# 71   51      47      63     50
# 77   90      78      83     37
# 82   23      85      92     84
# 84   45      83      77     37
# 86   64      36      98     80
# 93    1      38      61     47
# 95   58      56      89     37
# 96   40      48      62      0
# 97   28      97      71     65
# 98   30      26      65     71

# %%
df1.loc[filter1]
# Out:
#     Age  Height  Weight  Speed
# 1    10      14      56     87
# 2    44      28      77     22
# 3    95      59      87     72
# 5    60      68      74     90
# 6    13      74      63     55
# 7    36       7      76     19
# 9     0       0      71     37
# 11   89      48      63     82
# 14   75      51      70     57
# 17   82      79      82     82
# 18   34      87      64     64
# 19   62      94      90     12
# 21   34      74      62     42
# 25   12       1      98     65
# 26   81      70      83     77
# 27   87      11      92     76
# 28   19      15      87      0
# 31   24      22      77     46
# 32   38      23      67     47
# 33   78      43      84     62
# 36   91      78      98     76
# 37   13      72      80     54
# 41   16      65      54      9
# 42   10      15      67     64
# 43   35       2      95     85
# 45   15      15      67     50
# 47   61      23      98     43
# 48   81      19      74     15
# 50   54      72      87     72
# 52   79      19      89     81
# 53   22      92      91     44
# 57   37      17      99     69
# 58   97      10     100     18
# 60   82      84      56     30
# 61  100      80      86     70
# 63   89      27      88     21
# 66   42      41      53     50
# 69   49      62      82     71
# 70   85      82      99     55
# 71   51      47      63     50
# 77   90      78      83     37
# 82   23      85      92     84
# 84   45      83      77     37
# 86   64      36      98     80
# 93    1      38      61     47
# 95   58      56      89     37
# 96   40      48      62      0
# 97   28      97      71     65
# 98   30      26      65     71

# %%
filter2 = df1['Age'] > 50

# %%
df1[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 3    95      59      87     72
# 5    60      68      74     90
# 11   89      48      63     82
# 14   75      51      70     57
# 17   82      79      82     82
# 19   62      94      90     12
# 26   81      70      83     77
# 27   87      11      92     76
# 33   78      43      84     62
# 36   91      78      98     76
# 47   61      23      98     43
# 48   81      19      74     15
# 50   54      72      87     72
# 52   79      19      89     81
# 58   97      10     100     18
# 60   82      84      56     30
# 61  100      80      86     70
# 63   89      27      88     21
# 70   85      82      99     55
# 71   51      47      63     50
# 77   90      78      83     37
# 86   64      36      98     80
# 95   58      56      89     37

# %%
df1.loc[filter1 & filter2]
# Out:
#     Age  Height  Weight  Speed
# 3    95      59      87     72
# 5    60      68      74     90
# 11   89      48      63     82
# 14   75      51      70     57
# 17   82      79      82     82
# 19   62      94      90     12
# 26   81      70      83     77
# 27   87      11      92     76
# 33   78      43      84     62
# 36   91      78      98     76
# 47   61      23      98     43
# 48   81      19      74     15
# 50   54      72      87     72
# 52   79      19      89     81
# 58   97      10     100     18
# 60   82      84      56     30
# 61  100      80      86     70
# 63   89      27      88     21
# 70   85      82      99     55
# 71   51      47      63     50
# 77   90      78      83     37
# 86   64      36      98     80
# 95   58      56      89     37

# %%
df1[filter1 | filter2]
# Out:
#     Age  Height  Weight  Speed
# 1    10      14      56     87
# 2    44      28      77     22
# 3    95      59      87     72
# 5    60      68      74     90
# 6    13      74      63     55
# ..  ...     ...     ...    ...
# 95   58      56      89     37
# 96   40      48      62      0
# 97   28      97      71     65
# 98   30      26      65     71
# 99   89      16       2     62
#
# [72 rows x 4 columns]
